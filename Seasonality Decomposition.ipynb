# %%
path = r"D:\Asus\Documents\archive\AAPL.csv"

# %%
import pandas as pd

# %%
stocks= pd.read_csv(path, parse_dates=["Date"], index_col='Date')

# %%
stocks
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.513393    0.515625    0.513393    0.513393    0.407747
# 1980-12-15    0.488839    0.488839    0.486607    0.486607    0.386473
# 1980-12-16    0.453125    0.453125    0.450893    0.450893    0.358108
# 1980-12-17    0.462054    0.464286    0.462054    0.462054    0.366972
# 1980-12-18    0.475446    0.477679    0.475446    0.475446    0.377609
# ...                ...         ...         ...         ...         ...
# 2019-11-19  267.899994  268.000000  265.390015  266.290009  266.290009
# 2019-11-20  265.540009  266.079987  260.399994  263.190002  263.190002
# 2019-11-21  263.690002  264.010010  261.179993  262.010010  262.010010
# 2019-11-22  262.589996  263.179993  260.839996  261.779999  261.779999
# 2019-11-25  262.709991  266.440002  262.519989  266.369995  266.369995
#
#                  Volume
# Date
# 1980-12-12  117258400.0
# 1980-12-15   43971200.0
# 1980-12-16   26432000.0
# 1980-12-17   21610400.0
# 1980-12-18   18362400.0
# ...                 ...
# 2019-11-19   19041800.0
# 2019-11-20   26558600.0
# 2019-11-21   30348800.0
# 2019-11-22   16331300.0
# 2019-11-25   21005100.0
#
# [9823 rows x 6 columns]

# %%
stocks.resample('M').mean()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-31    0.544299    0.545845    0.543613    0.543613    0.431748
# 1981-01-31    0.567071    0.568346    0.565264    0.565264    0.448944
# 1981-02-28    0.472862    0.474506    0.471570    0.471570    0.374530
# 1981-03-31    0.445312    0.446733    0.443486    0.443486    0.352226
# 1981-04-30    0.487245    0.488733    0.486182    0.486182    0.386135
# ...                ...         ...         ...         ...         ...
# 2019-07-31  205.051817  206.729545  203.914090  205.216364  203.827658
# 2019-08-31  205.262274  207.609546  202.849546  204.957728  204.137486
# 2019-09-30  217.727499  219.471001  215.939500  217.994999  217.342478
# 2019-10-31  234.929565  236.969131  232.945218  235.286521  234.582242
# 2019-11-30  260.868230  262.711176  259.478237  261.825298  261.644346
#
#                   Volume
# Date
# 1980-12-31  2.586252e+07
# 1981-01-31  7.249867e+06
# 1981-02-28  4.231832e+06
# 1981-03-31  7.962691e+06
# 1981-04-30  6.392000e+06
# ...                  ...
# 2019-07-31  2.153871e+07
# 2019-08-31  3.095825e+07
# 2019-09-30  2.712836e+07
# 2019-10-31  2.644794e+07
# 2019-11-30  2.318037e+07
#
# [468 rows x 6 columns]

# %%
stocks['Close'].resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stocks['Close'].resample('Y').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stocks['Close'].resample('Q').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=[20,10])
stocks['Close'].resample('Y').mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pd.date_range(start= "01/01/2022", periods=45, freq= 'H')
# Out:
# DatetimeIndex(['2022-01-01 00:00:00', '2022-01-01 01:00:00',
#                '2022-01-01 02:00:00', '2022-01-01 03:00:00',
#                '2022-01-01 04:00:00', '2022-01-01 05:00:00',
#                '2022-01-01 06:00:00', '2022-01-01 07:00:00',
#                '2022-01-01 08:00:00', '2022-01-01 09:00:00',
#                '2022-01-01 10:00:00', '2022-01-01 11:00:00',
#                '2022-01-01 12:00:00', '2022-01-01 13:00:00',
#                '2022-01-01 14:00:00', '2022-01-01 15:00:00',
#                '2022-01-01 16:00:00', '2022-01-01 17:00:00',
#                '2022-01-01 18:00:00', '2022-01-01 19:00:00',
#                '2022-01-01 20:00:00', '2022-01-01 21:00:00',
#                '2022-01-01 22:00:00', '2022-01-01 23:00:00',
#                '2022-01-02 00:00:00', '2022-01-02 01:00:00',
#                '2022-01-02 02:00:00', '2022-01-02 03:00:00',
#                '2022-01-02 04:00:00', '2022-01-02 05:00:00',
#                '2022-01-02 06:00:00', '2022-01-02 07:00:00',
#                '2022-01-02 08:00:00', '2022-01-02 09:00:00',
#                '2022-01-02 10:00:00', '2022-01-02 11:00:00',
#                '2022-01-02 12:00:00', '2022-01-02 13:00:00',
#                '2022-01-02 14:00:00', '2022-01-02 15:00:00',
#                '2022-01-02 16:00:00', '2022-01-02 17:00:00',
#                '2022-01-02 18:00:00', '2022-01-02 19:00:00',
#                '2022-01-02 20:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\asus\anaconda31\lib\site-packages (0.13.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: patsy>=0.5.2 in c:\users\asus\anaconda31\lib\site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: scipy>=1.3 in c:\users\asus\anaconda31\lib\site-packages (from statsmodels) (1.7.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\asus\anaconda31\lib\site-packages (from statsmodels) (1.3.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\asus\anaconda31\lib\site-packages (from statsmodels) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\asus\anaconda31\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\asus\anaconda31\lib\site-packages (from pandas>=0.25->statsmodels) (2021.1)
# Requirement already satisfied: six in c:\users\asus\appdata\roaming\python\python38\site-packages (from patsy>=0.5.2->statsmodels) (1.15.0)
# Error processing line 1 of C:\Users\Asus\anaconda31\lib\site-packages\matplotlib-3.4.2-py3.8-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "C:\Users\Asus\anaconda31\lib\site.py", line 169, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 553, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored

# %%
stocks=stocks.asfreq('M', method='pad')

# %%
stocks.resample('M').sum()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-31    0.611607    0.611607    0.609375    0.609375    0.483978
# 1981-01-31    0.508929    0.508929    0.504464    0.504464    0.400656
# 1981-02-28    0.473214    0.477679    0.473214    0.473214    0.375836
# 1981-03-31    0.441964    0.441964    0.437500    0.437500    0.347471
# 1981-04-30    0.506696    0.511161    0.506696    0.506696    0.402429
# ...                ...         ...         ...         ...         ...
# 2019-06-30  198.679993  199.500000  197.050003  197.919998  196.580658
# 2019-07-31  216.419998  221.369995  211.300003  213.039993  211.598358
# 2019-08-31  210.160004  210.449997  207.199997  208.740005  208.115189
# 2019-09-30  220.899994  224.580002  220.789993  223.970001  223.299591
# 2019-10-31  247.240005  249.169998  237.259995  248.759995  248.015381
#
#                 Volume
# Date
# 1980-12-31   8937600.0
# 1981-01-31  11547200.0
# 1981-02-28   3690400.0
# 1981-03-31   3998400.0
# 1981-04-30   3152800.0
# ...                ...
# 2019-06-30  31110600.0
# 2019-07-31  69281400.0
# 2019-08-31  21143400.0
# 2019-09-30  25977400.0
# 2019-10-31  34790500.0
#
# [467 rows x 6 columns]

# %%
stocks
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-31    0.611607    0.611607    0.609375    0.609375    0.483978
# 1981-01-31    0.508929    0.508929    0.504464    0.504464    0.400656
# 1981-02-28    0.473214    0.477679    0.473214    0.473214    0.375836
# 1981-03-31    0.441964    0.441964    0.437500    0.437500    0.347471
# 1981-04-30    0.506696    0.511161    0.506696    0.506696    0.402429
# ...                ...         ...         ...         ...         ...
# 2019-06-30  198.679993  199.500000  197.050003  197.919998  196.580658
# 2019-07-31  216.419998  221.369995  211.300003  213.039993  211.598358
# 2019-08-31  210.160004  210.449997  207.199997  208.740005  208.115189
# 2019-09-30  220.899994  224.580002  220.789993  223.970001  223.299591
# 2019-10-31  247.240005  249.169998  237.259995  248.759995  248.015381
#
#                 Volume
# Date
# 1980-12-31   8937600.0
# 1981-01-31  11547200.0
# 1981-02-28   3690400.0
# 1981-03-31   3998400.0
# 1981-04-30   3152800.0
# ...                ...
# 2019-06-30  31110600.0
# 2019-07-31  69281400.0
# 2019-08-31  21143400.0
# 2019-09-30  25977400.0
# 2019-10-31  34790500.0
#
# [467 rows x 6 columns]

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot
# series = ...
result = seasonal_decompose(stocks['Close'], model='multiplicative')
# plt.figure(figsize=[10,10])
from pylab import rcParams
rcParams['figure.figsize']=20,18
result.plot()
pyplot.show()

# %%
log_stocks= stocks.copy()

# %%
log_stocks= np.log(log_stocks)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from matplotlib import pyplot
# series = ...
result = seasonal_decompose(log_stocks['Close'], model='additive')
# plt.figure(figsize=[10,10])
from pylab import rcParams
rcParams['figure.figsize']=20,18
result.plot()
pyplot.show()
